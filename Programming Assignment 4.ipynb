# %% [markdown]
# # ECE2112 PROGRAMMING ASSIGNMENT #4

# %% [markdown]
# # BY: LANZ JOSEPH S. PELAYO || 2ECE-B || SUBMITTED AND PRODUCED ON SEPTEMBER 17, 2026.

# %% [markdown]
# importing Pandas and Matplot libraries in the notebook

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Setting up the data set

# %%
board = pd.read_excel('board2.xlsx')
board['Average'] = board[['Math','Electronics', 'GEAS', 'Communication']].mean(axis=1)
board
# Out:
#    Name  Gender             Track  Hometown  Math  Electronics  GEAS  \
# 0    S1    Male   Instrumentation     Luzon    58           89    75
# 1    S2  Female     Communication  Mindanao    52           75    90
# 2    S3  Female   Instrumentation  Mindanao    83           74    77
# 3    S4    Male   Instrumentation   Visayas    65           58    91
# 4    S5    Male     Communication     Luzon    59           86    43
# 5    S6  Female  Microelectronics   Visayas    88           45    86
# 6    S7  Female   Instrumentation     Luzon    66           60    60
# 7    S8    Male   Instrumentation     Luzon    49           81    64
# 8    S9    Male   Instrumentation     Luzon    50           36    63
# 9   S10    Male  Microelectronics  Mindanao    80           84    61
# 10  S11  Female     Communication   Visayas    48           56    48
# 11  S12    Male     Communication   Visayas    89           67    84
# 12  S13  Female  Microelectronics     Luzon    88           35    83
# ...

# %% [markdown]
# # A. VISAYAS COMMUNICATION DATAFRAME

# %%
VisComm = board.loc[(board['Hometown'] == 'Visayas') & (board['Track'] == 'Communication') ,['Name', 'Gender','Math', 'Electronics', 'Average']]

# %%
#Required Check #A.1: 
VisComm
# Out:
#    Name  Gender  Math  Electronics  Average
# 10  S11  Female    48           56    54.75
# 11  S12    Male    89           67    76.00
# 17  S18    Male    81           40    63.50
# 21  S22  Female    64           39    62.50
# 27  S28    Male    85           53    67.75

# %%
#Required Check #A.2:
VisComm.shape[0]
# Out:
# 5

# %% [markdown]
# # B. VISAYAS FEMALE DATAFRAME

# %%
VisFemale = board.loc[(board['Hometown'] == 'Visayas') & (board['Gender'] == 'Female'),['Name', 'Track', 'GEAS', 'Electronics', 'Average']]
VisFemale
# Out:
#    Name             Track  GEAS  Electronics  Average
# 5    S6  Microelectronics    86           45    75.50
# 10  S11     Communication    48           56    54.75
# 20  S21  Microelectronics    68           51    68.50
# 21  S22     Communication    89           39    62.50
# 23  S24  Microelectronics    60           45    57.75
# 25  S26   Instrumentation    83           47    65.75

# %%
#Required Check #B.1:
VisFemale
# Out:
#    Name             Track  GEAS  Electronics  Average
# 5    S6  Microelectronics    86           45    75.50
# 10  S11     Communication    48           56    54.75
# 20  S21  Microelectronics    68           51    68.50
# 21  S22     Communication    89           39    62.50
# 23  S24  Microelectronics    60           45    57.75
# 25  S26   Instrumentation    83           47    65.75

# %%
#Required Check #B.2:
VisFemale.loc[VisFemale['Average'] >=60]
# Out:
#    Name             Track  GEAS  Electronics  Average
# 5    S6  Microelectronics    86           45    75.50
# 20  S21  Microelectronics    68           51    68.50
# 21  S22     Communication    89           39    62.50
# 25  S26   Instrumentation    83           47    65.75

# %% [markdown]
# # C. CATEGORY-AVERAGE VISUALIZATION

# %%
#Required Check #C.1:
trackmean = board.groupby('Track')['Average'].mean()
gendermean = board.groupby('Gender')['Average'].mean()
hometownmean = board.groupby('Hometown')['Average'].mean()

# %%
#Required Check #C.2:
trackmean
# Out:
# Track
# Communication       67.975
# Instrumentation     65.225
# Microelectronics    67.500
# Name: Average, dtype: float64

# %%
gendermean
# Out:
# Gender
# Female    66.616667
# Male      67.183333
# Name: Average, dtype: float64

# %%
hometownmean
# Out:
# Hometown
# Luzon       68.083333
# Mindanao    66.678571
# Visayas     65.750000
# Name: Average, dtype: float64

# %%
#Required Check #C.3:
fig, ax= plt.subplots( 1, 3, figsize = (15,5))
trackmean.plot(kind='bar', ax=ax[0], title = 'Average Score By Track', ylabel = 'Average Scores', color= 'teal', rot = 0, fontsize = 9, ylim = (0,100))
gendermean.plot(kind='bar', ax=ax[1], title = 'Average Score By Gender', ylabel = 'Average Scores', color= 'Purple', rot = 0, ylim = (0,100))
hometownmean.plot(kind= 'bar', ax=ax[2], title = 'Average Score By Hometown', ylabel = 'Average Scores', color= '#012db9', rot = 0, ylim = (0,100)) 
plt.show()

# %% [markdown]
# Required Check #C.4:\
# Track = Students who have scored the highest average test mean scores by track were the Communications track getting a mean score of 67.98.\
# Gender = Male Students  have achieved the highest mean average score than Female students with a mean score of 67.18.\
# Hometown = Students who resided in Luzon scored the highest in their average mean scores in the ECE board exam with a mean score of 68.08.
